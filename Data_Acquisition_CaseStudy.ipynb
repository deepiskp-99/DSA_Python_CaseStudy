# %% [markdown]
# <a href="https://colab.research.google.com/github/deepiskp-99/DSA_Python_CaseStudy/blob/main/Data_Acquisition_CaseStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**1.Extract Data**

# %% [markdown]
# **1.Load the CSV file using pandas.read_csv()**

# %%
import pandas as pd

# %%
population = pd.read_csv("/content/population.csv")
population
# Out:
#            country  population
# 0    United States  1278642419
# 1            China   792846414
# 2            India  1001406378
# 3            Japan  1206263687
# 4          Germany   428734972
# 5           Russia   420968276
# 6           Brazil   675094950
# 7   United Kingdom   674991378
# 8           France   434389014
# 9            Italy   254467210
# 10          Canada  1438267572
# 11       Australia   439285667
# 12     South Korea   618608295
# 13           Spain   898664919
# 14          Mexico   653061058
# 15       Indonesia    93409749
# 16          Turkey   247285876
# 17    Saudi Arabia   958477463
# 18       Argentina  1432830251
# 19    South Africa   916989541

# %% [markdown]
# **2.Load the Excel file using pandas.read_excel()**

# %%
gdp = pd.read_excel("/content/gdp.xlsx")
gdp
# Out:
#            Country             GDP
# 0    United States  10450436373455
# 1            China   5086547998939
# 2            India  14540718118693
# 3            Japan  12473835857216
# 4          Germany   2038442396490
# 5           Russia  10987125474745
# 6           Brazil   8793052816619
# 7   United Kingdom  11799848684255
# 8           France   7758669752269
# 9            Italy  12907234326850
# 10          Canada   8158351525190
# 11       Australia   5444267975247
# 12     South Korea   6562909541266
# 13           Spain  15275513099842
# 14          Mexico   2775281278756
# 15       Indonesia  12404144955318
# 16          Turkey   2581127745611
# 17    Saudi Arabia   8855399647233
# 18       Argentina   8767336567320
# 19    South Africa   3328747361982

# %% [markdown]
# **3.Load the JSON file using Python’s json module**

# %%
i_u =pd.read_json("/content/internet_users.json")
i_u
# Out:
#            country  internet_users
# 0    United States       745595490
# 1            China       685275917
# 2            India       606850704
# 3            Japan      1112451555
# 4          Germany       246827121
# 5           Russia       162156967
# 6           Brazil        24027075
# 7   United Kingdom       266047041
# 8           France       216417853
# 9            Italy        87191493
# 10          Canada       894102645
# 11       Australia       201619113
# 12     South Korea       291770691
# 13           Spain       794943861
# 14          Mexico       135489564
# 15       Indonesia         4584702
# 16          Turkey       128924625
# 17    Saudi Arabia       108944665
# 18       Argentina       421477197
# 19    South Africa       739194223

# %% [markdown]
# **4.Parse the XML file using xml.etree.ElementTree**

# %%
lit_rate = pd.read_xml("/content/literacy_rate.xml")
lit_rate
# Out:
#               name  literacy_rate
# 0    United States           72.7
# 1            China           82.2
# 2            India           80.3
# 3            Japan           97.5
# 4          Germany           92.9
# 5           Russia           89.1
# 6           Brazil           81.0
# 7   United Kingdom           82.9
# 8           France           97.6
# 9            Italy           83.7
# 10          Canada           70.8
# 11       Australia           71.6
# 12     South Korea           66.4
# 13           Spain           60.6
# 14          Mexico           76.5
# 15       Indonesia           75.4
# 16          Turkey           71.4
# 17    Saudi Arabia           60.5
# 18       Argentina           67.8
# 19    South Africa           87.7

# %% [markdown]
# #**2.Transform Data**

# %% [markdown]
# **5.Standardize country names across all datasets**

# %%
literacy_rate =lit_rate.rename(columns={'name':'country'})
literacy_rate
# Out:
#            country  literacy_rate
# 0    United States           72.7
# 1            China           82.2
# 2            India           80.3
# 3            Japan           97.5
# 4          Germany           92.9
# 5           Russia           89.1
# 6           Brazil           81.0
# 7   United Kingdom           82.9
# 8           France           97.6
# 9            Italy           83.7
# 10          Canada           70.8
# 11       Australia           71.6
# 12     South Korea           66.4
# 13           Spain           60.6
# 14          Mexico           76.5
# 15       Indonesia           75.4
# 16          Turkey           71.4
# 17    Saudi Arabia           60.5
# 18       Argentina           67.8
# 19    South Africa           87.7

# %%
gdp_data = gdp.rename(columns ={'Country': 'COUNTRY'})
gdp_data
# Out:
#            COUNTRY             GDP
# 0    United States  10450436373455
# 1            China   5086547998939
# 2            India  14540718118693
# 3            Japan  12473835857216
# 4          Germany   2038442396490
# 5           Russia  10987125474745
# 6           Brazil   8793052816619
# 7   United Kingdom  11799848684255
# 8           France   7758669752269
# 9            Italy  12907234326850
# 10          Canada   8158351525190
# 11       Australia   5444267975247
# 12     South Korea   6562909541266
# 13           Spain  15275513099842
# 14          Mexico   2775281278756
# 15       Indonesia  12404144955318
# 16          Turkey   2581127745611
# 17    Saudi Arabia   8855399647233
# 18       Argentina   8767336567320
# 19    South Africa   3328747361982

# %% [markdown]
# **6.Convert numeric columns to appropriate types**

# %%
population['population'].dtype
# Out:
# dtype('int64')

# %%
gdp['GDP'].dtype
# Out:
# dtype('int64')

# %%
i_u['internet_users'].dtype
# Out:
# dtype('int64')

# %%
lit_rate["literacy_rate"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **7.Handle missing or erroneous data**

# %%
population.isnull().sum()
# Out:
# country       0
# population    0
# dtype: int64

# %%
gdp.isnull().sum()
# Out:
# Country    0
# GDP        0
# dtype: int64

# %%
i_u.isnull().sum()
# Out:
# country           0
# internet_users    0
# dtype: int64

# %%
lit_rate.isnull().sum()
# Out:
# name             0
# literacy_rate    0
# dtype: int64

# %% [markdown]
# **8.Create new columns such as internet penetration rate (internet users / population × 100)**

# %%
i_u['internet_penetration_rate'] =i_u['internet_users']/population['population']*100

# %%
del i_u['internet_penetration_rate']

# %%
i_u
# Out:
#            country  internet_users  internet_penetration_rate
# 0    United States       745595490                  58.311493
# 1            China       685275917                  86.432366
# 2            India       606850704                  60.599844
# 3            Japan      1112451555                  92.222917
# 4          Germany       246827121                  57.571026
# 5           Russia       162156967                  38.519997
# 6           Brazil        24027075                   3.559066
# 7   United Kingdom       266047041                  39.414880
# 8           France       216417853                  49.821208
# 9            Italy        87191493                  34.264333
# 10          Canada       894102645                  62.165251
# 11       Australia       201619113                  45.897039
# 12     South Korea       291770691                  47.165661
# 13           Spain       794943861                  88.458317
# ...

# %% [markdown]
# #**3.Integrate Data**

# %% [markdown]
# **9.Merge the datasets based on the country name**

# %%
data_set = pd.merge(population,literacy_rate, on='country', how='outer')

gdp_data = gdp_data.rename(columns={'COUNTRY': 'country'})

data_set = pd.merge(data_set, i_u, on='country', how='outer')

data_set = pd.merge(data_set , gdp_data, on='country', how='outer')

display(data_set)
# Out:
#            country  population  literacy_rate  internet_users  \
# 0        Argentina  1432830251           67.8       421477197
# 1        Australia   439285667           71.6       201619113
# 2           Brazil   675094950           81.0        24027075
# 3           Canada  1438267572           70.8       894102645
# 4            China   792846414           82.2       685275917
# 5           France   434389014           97.6       216417853
# 6          Germany   428734972           92.9       246827121
# 7            India  1001406378           80.3       606850704
# 8        Indonesia    93409749           75.4         4584702
# 9            Italy   254467210           83.7        87191493
# 10           Japan  1206263687           97.5      1112451555
# 11          Mexico   653061058           76.5       135489564
# 12          Russia   420968276           89.1       162156967
# 13    Saudi Arabia   958477463           60.5       108944665
# ...

# %% [markdown]
# **10.Handle unmatched or missing records**

# %%
mis_data = data_set.isna().sum()
mis_data
# Out:
# country                      0
# population                   0
# literacy_rate                0
# internet_users               0
# internet_penetration_rate    0
# GDP                          0
# dtype: int64

# %% [markdown]
# **11.Validate the data for consistency and completeness**

# %%
print("data_types:\n", data_set.dtypes)
# Out:
# data_types:
#  country                       object
# population                     int64
# literacy_rate                float64
# internet_users                 int64
# internet_penetration_rate    float64
# GDP                            int64
# dtype: object

# %%
inv_lit = data_set[(data_set['literacy_rate'] < 0) | (data_set['literacy_rate'] > 100)]
inv_lit

inv_pop = data_set[data_set['population'] <= 0]
inv_pop


inv_pen = data_set[(data_set['internet_penetration_rate'] < 0) | (data_set['internet_penetration_rate'] > 100)]
inv_pen
# Out:
# Empty DataFrame
# Columns: [country, population, literacy_rate, internet_users, internet_penetration_rate, GDP]
# Index: []

# %% [markdown]
# #**4.Analyze Data**

# %% [markdown]
# **12.Find countries with highest internet penetration rates**

# %%
data_set.sort_values('internet_penetration_rate', ascending= False)
# Out:
#            country  population  literacy_rate  internet_users  \
# 10           Japan  1206263687           97.5      1112451555
# 16           Spain   898664919           60.6       794943861
# 4            China   792846414           82.2       685275917
# 14    South Africa   916989541           87.7       739194223
# 3           Canada  1438267572           70.8       894102645
# 7            India  1001406378           80.3       606850704
# 19   United States  1278642419           72.7       745595490
# 6          Germany   428734972           92.9       246827121
# 17          Turkey   247285876           71.4       128924625
# 5           France   434389014           97.6       216417853
# 15     South Korea   618608295           66.4       291770691
# 1        Australia   439285667           71.6       201619113
# 18  United Kingdom   674991378           82.9       266047041
# 12          Russia   420968276           89.1       162156967
# ...

# %% [markdown]
# **13.Calculate average literacy rate across countries**

# %%
avg_rate = data_set["literacy_rate"].mean()
print("Average Literacy Rate across countries:", avg_rate)
# Out:
# Average Literacy Rate across countries: 78.43

# %% [markdown]
# **14.Investigate relationships between GDP, population, literacy, and internet usage**

# %%
corr = data_set[["GDP", "population", "literacy_rate", "internet_users"]].corr()
print(corr)
# Out:
#                      GDP  population  literacy_rate  internet_users
# GDP             1.000000    0.183118      -0.081700        0.212559
# population      0.183118    1.000000      -0.229585        0.749573
# literacy_rate  -0.081700   -0.229585       1.000000        0.074808
# internet_users  0.212559    0.749573       0.074808        1.000000

# %% [markdown]
# #**5.Load an SQLite**

# %% [markdown]
# **15.Create an SQLite database**

# %%
import sqlite3

conn = sqlite3.connect("data")

cursor = conn.cursor()

# %% [markdown]
# **16.Load the final merged dataset into a database table**

# %%
sql = data_set.to_sql("final_data", conn, if_exists='replace',index=False)
sql
# Out:
# 20

# %%
cursor = conn.cursor()

cursor.execute("SELECT * FROM final_data LIMIT 5")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Argentina', 1432830251, 67.8, 421477197, 29.415710388990107, 8767336567320)
# ('Australia', 439285667, 71.6, 201619113, 45.89703879412028, 5444267975247)
# ('Brazil', 675094950, 81.0, 24027075, 3.559066024712524, 8793052816619)
# ('Canada', 1438267572, 70.8, 894102645, 62.165250917581005, 8158351525190)
# ('China', 792846414, 82.2, 685275917, 86.4323663321759, 5086547998939)

# %% [markdown]
# #**6.Write and execute SQL queries to extract insights**

# %% [markdown]
# **17.Countries with highest internet penetration**

# %%
cursor.execute("""SELECT country, internet_penetration_rate
FROM final_data
ORDER BY internet_penetration_rate DESC
LIMIT 10""" )
rows = cursor.fetchall()
for i in rows:
  print(i)
# Out:
# ('Japan', 92.22291667974251)
# ('Spain', 88.45831679783196)
# ('China', 86.4323663321759)
# ('South Africa', 80.61097645605535)
# ('Canada', 62.165250917581005)
# ('India', 60.59984411243684)
# ('United States', 58.311493418395656)
# ('Germany', 57.57102571982394)
# ('Turkey', 52.135862785790486)
# ('France', 49.82120772511065)

# %% [markdown]
# **18.Average literacy rate**

# %%
cursor.execute("SELECT AVG(literacy_rate) FROM final_data")
print(" Average Literacy Rate:", cursor.fetchone()[0])
# Out:
#  Average Literacy Rate: 78.43

# %% [markdown]
# **19.Correlation between literacy rate and internet penetration**

# %%
cursor.execute("""SELECT
    (AVG( internet_penetration_rate	* literacy_rate) - AVG(internet_penetration_rate	) * AVG(literacy_rate)) /
    (SQRT((AVG(internet_penetration_rate	 * internet_penetration_rate	) - AVG(internet_penetration_rate	)*AVG(internet_penetration_rate	)) *
          (AVG(literacy_rate * literacy_rate) - AVG(literacy_rate)*AVG(literacy_rate))))
    AS correlation
FROM final_data;""")

print(cursor.fetchall())
# Out:
# [(0.23533009202708055,)]

# %% [markdown]
# **20.GDP per capita analysis**

# %%
cursor.execute("""
SELECT Country,
       ROUND(GDP / Population, 2) AS gdp_per_capita
FROM final_data

""")

print(cursor.fetchall())
# Out:
# [('Argentina', 6118.0), ('Australia', 12393.0), ('Brazil', 13024.0), ('Canada', 5672.0), ('China', 6415.0), ('France', 17861.0), ('Germany', 4754.0), ('India', 14520.0), ('Indonesia', 132792.0), ('Italy', 50722.0), ('Japan', 10340.0), ('Mexico', 4249.0), ('Russia', 26099.0), ('Saudi Arabia', 9239.0), ('South Africa', 3630.0), ('South Korea', 10609.0), ('Spain', 16998.0), ('Turkey', 10437.0), ('United Kingdom', 17481.0), ('United States', 8173.0)]

# %% [markdown]
# **21.Which countries have a GDP per capita above $10,000?**

# %%
cursor.execute("""SELECT country
FROM final_data
WHERE ROUND(GDP / population, 2) > 10000""")
print(cursor.fetchall())
# Out:
# [('Australia',), ('Brazil',), ('France',), ('India',), ('Indonesia',), ('Italy',), ('Japan',), ('Russia',), ('South Korea',), ('Spain',), ('Turkey',), ('United Kingdom',)]

# %% [markdown]
# **22.What is the total population covered in the dataset?**

# %%
cursor.execute(""" SELECT SUM(Population) AS total_population
FROM final_data;
""")
print(cursor.fetchall())
# Out:
# [(14864685089,)]

# %% [markdown]
# **23.Which countries have the lowest literacy rates, and how does that impact internet access?**

# %%
cursor.execute("""SELECT Country,literacy_rate,internet_penetration_rate
FROM final_data
ORDER BY literacy_rate ASC;""")

lowest_literacy_countries = cursor.fetchmany(10)

for row in lowest_literacy_countries:
    print(f"Country: {row[0]}, Literacy Rate: {row[1]}, Internet Penetration Rate: {row[2]}")
# Out:
# Country: Saudi Arabia, Literacy Rate: 60.5, Internet Penetration Rate: 11.36642948901554
# Country: Spain, Literacy Rate: 60.6, Internet Penetration Rate: 88.45831679783196
# Country: South Korea, Literacy Rate: 66.4, Internet Penetration Rate: 47.165660945429124
# Country: Argentina, Literacy Rate: 67.8, Internet Penetration Rate: 29.415710388990107
# Country: Canada, Literacy Rate: 70.8, Internet Penetration Rate: 62.165250917581005
# Country: Turkey, Literacy Rate: 71.4, Internet Penetration Rate: 52.135862785790486
# Country: Australia, Literacy Rate: 71.6, Internet Penetration Rate: 45.89703879412028
# Country: United States, Literacy Rate: 72.7, Internet Penetration Rate: 58.311493418395656
# Country: Indonesia, Literacy Rate: 75.4, Internet Penetration Rate: 4.9081622090644945
# Country: Mexico, Literacy Rate: 76.5, Internet Penetration Rate: 20.74684477664874

# %% [markdown]
# **24.What are the top 5 wealthiest countries by total GDP, and how does that compare with population size?**

# %%
cursor.execute(""" SELECT
    Country,
    Population,
    GDP,
    (GDP * Population) AS GDP_total
FROM final_data
ORDER BY GDP_total DESC
LIMIT 5;
""")

wealtheast_countries = cursor.fetchall()

for row in wealtheast_countries:
    print(f"Country: {row[0]}, population: {row[1]}, GDP: {row[2]}")
# Out:
# Country: Japan, population: 1206263687, GDP: 12473835857216
# Country: India, population: 1001406378, GDP: 14540718118693
# Country: Spain, population: 898664919, GDP: 15275513099842
# Country: United States, population: 1278642419, GDP: 10450436373455
# Country: Argentina, population: 1432830251, GDP: 8767336567320

# %% [markdown]
# **25.Find countries where internet users exceed 70% of the population.**

# %%
cursor.execute(""" SELECT Country,internet_penetration_rate,population
FROM final_data
WHERE internet_penetration_rate > 70
ORDER BY internet_penetration_rate DESC;
""")

internet_70 = cursor.fetchall()

for row in internet_70:
    print(f"Country: {row[0]},internet_penetration_rate : {row[1]}, population:{row[2]}")
# Out:
# Country: Japan,internet_penetration_rate : 92.22291667974251, population:1206263687
# Country: Spain,internet_penetration_rate : 88.45831679783196, population:898664919
# Country: China,internet_penetration_rate : 86.4323663321759, population:792846414
# Country: South Africa,internet_penetration_rate : 80.61097645605535, population:916989541

# %% [markdown]
# **26.What is the average GDP per capita for countries with internet penetration above 50**

# %%
cursor.execute(""" SELECT country, AVG(GDP) AS avg_gdp_per_capita_high_internet
FROM final_data
WHERE internet_penetration_rate > 50;
""")
print(cursor.fetchall())
# Out:
# [('Canada', 8214857830824.223)]

# %% [markdown]
# **27.How many countries have a literacy rate above 90%, and what is their average internet penetration?**

# %%
cursor.execute("""select country, AVG(literacy_rate), AVG(internet_penetration_rate)
from final_data
where literacy_rate >90
""")
print(cursor.fetchall())
# Out:
# [('France', 96.0, 66.53838337489236)]

# %%
conn.close()
